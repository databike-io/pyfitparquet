# %%
import sys, os, time, re
import pandas as pd
import pyarrow

sys.path.append('../cpp/fit-build')
from pyfitparquet_so import FPTransformer

# %%
# USER: must set FIT_DATA_DIR to location of .fit files
# Defaults PARQUET_DIR to subdirectory within FIT_DATA_DIR

FIT_DATA_DIR = '../../data'
PARQUET_DIR = FIT_DATA_DIR + '/parquet'

try: os.mkdir(PARQUET_DIR)
except FileExistsError: pass

# %%
# Serializes all files in FIT_DATA_DIR

parquetfiles = []
transformer = FPTransformer()
for file in os.listdir(FIT_DATA_DIR):
#{
    matchobj = re.match('(\w+).fit', file)
    if matchobj:
    #{
        fitfile = f"{FIT_DATA_DIR}/{file}"
        parquetfile = f"{PARQUET_DIR}/{matchobj.group(1)}.parquet"
        print(f"Serializing {fitfile} => {parquetfile}")
        
        initial = time.time()
        if transformer.fit_to_parquet(fitfile, parquetfile) == 0:
            print(f"Serialization completed in {time.time()-initial:.3f} sec\n")
            parquetfiles.append(parquetfile)
    #}
#}
# Out:
# Serializing ../../data/Bolt_GPS.fit => ../../data/parquet/Bolt_GPS.parquet
# Serialization completed in 13.264 sec
#
# Serializing ../../data/Who_Dares_Whoop.fit => ../../data/parquet/Who_Dares_Whoop.parquet
# Serialization completed in 0.161 sec
#
# Serializing ../../data/Who_Dares_Bolt.fit => ../../data/parquet/Who_Dares_Bolt.parquet
# Serialization completed in 0.878 sec
#
# Serializing ../../data/Who_Dares_Sufferfest.fit => ../../data/parquet/Who_Dares_Sufferfest.parquet
# Serialization completed in 0.587 sec

# %%
# Opens transformed parquet files into
# dataframes and display their summaries

dframes = {}
for pfile in parquetfiles:
    pdframe = pd.read_parquet(pfile, engine='pyarrow')
    dframes[pfile] = pdframe
    print(pfile + ":")
    display(pdframe)
    #display(dframe[60:120])
    print()
# Out:
# ../../data/parquet/Bolt_GPS.parquet:
#        source_filetype source_filename manufacturer_name  product_index  \
# 0                  FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 1                  FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 2                  FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 3                  FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 4                  FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# ...                ...             ...               ...            ...
# 360351             FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 360352             FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 360353             FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 360354             FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
# 360355             FIT    Bolt_GPS.fit     WAHOO_FITNESS             31
#
#                  timestamp mesg_name  field_index        field_name  \
# 0      2020-08-30 16:48:11   file_id            4      time_created
# 1      2020-08-30 16:48:11   file_id            0              type
# 2      2020-08-30 16:48:11   file_id            1      manufacturer
# 3      2020-08-30 16:48:11   file_id            2           product
# 4      2020-08-30 16:48:11   file_id            3     serial_number
# ...                    ...       ...          ...               ...
# 360351 2020-08-30 22:49:26  activity            1      num_sessions
# 360352 2020-08-30 22:49:26  activity            2              type
# 360353 2020-08-30 22:49:26  activity            3             event
# 360354 2020-08-30 22:49:26  activity            4        event_type
# 360355 2020-08-30 22:49:26  activity            0  total_timer_time
#
#        field_type  value_string   value_float units
# 0           float   967740491.0  9.677405e+08  None
# 1           float           4.0  4.000000e+00  None
# 2           float          32.0  3.200000e+01  None
# 3           float          31.0  3.100000e+01  None
# 4           float  3338297344.0  3.338297e+09  None
# ...           ...           ...           ...   ...
# 360351      float           1.0  1.000000e+00  None
# 360352      float           0.0  0.000000e+00  None
# 360353      float          26.0  2.600000e+01  None
# 360354      float           1.0  1.000000e+00  None
# 360355      float       21676.0  2.167600e+04     s
#
# [360356 rows x 12 columns]
# ../../data/parquet/Who_Dares_Whoop.parquet:
#      source_filetype      source_filename manufacturer_name  product_index  \
# 0                FIT  Who_Dares_Whoop.fit             WHOOP              3
# 1                FIT  Who_Dares_Whoop.fit             WHOOP              3
# 2                FIT  Who_Dares_Whoop.fit             WHOOP              3
# 3                FIT  Who_Dares_Whoop.fit             WHOOP              3
# 4                FIT  Who_Dares_Whoop.fit             WHOOP              3
# ...              ...                  ...               ...            ...
# 5407             FIT  Who_Dares_Whoop.fit             WHOOP              3
# 5408             FIT  Who_Dares_Whoop.fit             WHOOP              3
# 5409             FIT  Who_Dares_Whoop.fit             WHOOP              3
# 5410             FIT  Who_Dares_Whoop.fit             WHOOP              3
# 5411             FIT  Who_Dares_Whoop.fit             WHOOP              3
#
#                timestamp mesg_name  field_index     field_name field_type  \
# 0                    NaT   file_id            1   manufacturer      float
# 1                    NaT   file_id            0           type      float
# 2                    NaT   file_id            2        product      float
# 3                    NaT   file_id            3  serial_number      float
# 4    2020-11-25 19:00:06   session          253      timestamp      float
# ...                  ...       ...          ...            ...        ...
# 5407 2020-11-25 19:43:21    record            3     heart_rate      float
# 5408 2020-11-25 19:43:22    record          253      timestamp      float
# 5409 2020-11-25 19:43:22    record            3     heart_rate      float
# 5410 2020-11-25 19:43:23    record          253      timestamp      float
# 5411 2020-11-25 19:43:23    record            3     heart_rate      float
#
#      value_string  value_float units
# 0           305.0        305.0  None
# 1             4.0          4.0  None
# 2             3.0          3.0  None
# 3         12345.0      12345.0  None
# 4     975265206.0  975265206.0     s
# ...           ...          ...   ...
# 5407        135.0        135.0   bpm
# 5408  975267802.0  975267802.0     s
# 5409        133.0        133.0   bpm
# 5410  975267803.0  975267803.0     s
# 5411        133.0        133.0   bpm
#
# [5412 rows x 12 columns]
# ../../data/parquet/Who_Dares_Bolt.parquet:
#       source_filetype     source_filename manufacturer_name  product_index  \
# 0                 FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 1                 FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 2                 FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 3                 FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 4                 FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# ...               ...                 ...               ...            ...
# 36394             FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36395             FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36396             FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36397             FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36398             FIT  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
#
#                 timestamp mesg_name  field_index        field_name field_type  \
# 0     2020-11-25 18:48:44   file_id            4      time_created      float
# 1     2020-11-25 18:48:44   file_id            0              type      float
# 2     2020-11-25 18:48:44   file_id            1      manufacturer      float
# 3     2020-11-25 18:48:44   file_id            2           product      float
# 4     2020-11-25 18:48:44   file_id            3     serial_number      float
# ...                   ...       ...          ...               ...        ...
# 36394 2020-11-25 19:43:38  activity            1      num_sessions      float
# 36395 2020-11-25 19:43:38  activity            2              type      float
# 36396 2020-11-25 19:43:38  activity            3             event      float
# 36397 2020-11-25 19:43:38  activity            4        event_type      float
# 36398 2020-11-25 19:43:38  activity            0  total_timer_time      float
#
#        value_string   value_float units
# 0       975264524.0  9.752645e+08  None
# 1               4.0  4.000000e+00  None
# 2              32.0  3.200000e+01  None
# 3              31.0  3.100000e+01  None
# 4      3338297344.0  3.338297e+09  None
# ...             ...           ...   ...
# 36394           1.0  1.000000e+00  None
# 36395           0.0  0.000000e+00  None
# 36396          26.0  2.600000e+01  None
# 36397           1.0  1.000000e+00  None
# 36398        3294.0  3.294000e+03     s
#
# [36399 rows x 12 columns]
# ../../data/parquet/Who_Dares_Sufferfest.parquet:
#       source_filetype           source_filename manufacturer_name  \
# 0                 FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 1                 FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 2                 FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 3                 FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 4                 FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# ...               ...                       ...               ...
# 22904             FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 22905             FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 22906             FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 22907             FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
# 22908             FIT  Who_Dares_Sufferfest.fit    THE_SUFFERFEST
#
#        product_index           timestamp mesg_name  field_index  \
# 0               1231 2020-11-25 18:48:03   file_id            0
# 1               1231 2020-11-25 18:48:03   file_id            1
# 2               1231 2020-11-25 18:48:03   file_id            2
# 3               1231 2020-11-25 18:48:03   file_id            3
# 4               1231 2020-11-25 18:48:03   file_id            4
# ...              ...                 ...       ...          ...
# 22904           1231 2020-11-25 19:42:13  activity            5
# 22905           1231 2020-11-25 19:42:13  activity            1
# 22906           1231 2020-11-25 19:42:13  activity            2
# 22907           1231 2020-11-25 19:42:13  activity            3
# 22908           1231 2020-11-25 19:42:13  activity            4
#
#             field_name field_type value_string  value_float units
# 0                 type      float          4.0          4.0  None
# 1         manufacturer      float        282.0        282.0  None
# 2              product      float       1231.0       1231.0  None
# 3        serial_number      float      12345.0      12345.0  None
# 4         time_created      float  975264483.0  975264483.0  None
# ...                ...        ...          ...          ...   ...
# 22904  local_timestamp      float          0.0          0.0  None
# 22905     num_sessions      float          1.0          1.0  None
# 22906             type      float          0.0          0.0  None
# 22907            event      float         26.0         26.0  None
# 22908       event_type      float          0.0          0.0  None
#
# [22909 rows x 12 columns]

# %%
# Test re-initialization from configuation file
# USER: make some change to parquet_config.yml

initial = time.time()
transformer.reset_from_config()
print(f"Re-serializing {fitfile} => {parquetfile}")
if transformer.fit_to_parquet(fitfile, parquetfile) == 0:
    print(f"Serialization completed in {time.time()-initial:.3f} sec\n")
    dframes[parquetfile] = pd.read_parquet(parquetfile, engine='pyarrow')
    display(dframes[parquetfile])
# Out:
# Re-serializing ../../data/Who_Dares_Sufferfest.fit => ../../data/parquet/Who_Dares_Sufferfest.parquet
# Serialization completed in 0.695 sec
#                 source_filename manufacturer_name  product_index  \
# 0      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 1      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 2      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 3      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 4      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# ...                         ...               ...            ...
# 22904  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22905  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22906  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22907  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22908  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
#
#                 timestamp mesg_name  field_index       field_name field_type  \
# 0     2020-11-25 18:48:03   file_id            0             type      float
# 1     2020-11-25 18:48:03   file_id            1     manufacturer      float
# 2     2020-11-25 18:48:03   file_id            2          product      float
# 3     2020-11-25 18:48:03   file_id            3    serial_number      float
# 4     2020-11-25 18:48:03   file_id            4     time_created      float
# ...                   ...       ...          ...              ...        ...
# 22904 2020-11-25 19:42:13  activity            5  local_timestamp      float
# 22905 2020-11-25 19:42:13  activity            1     num_sessions      float
# 22906 2020-11-25 19:42:13  activity            2             type      float
# 22907 2020-11-25 19:42:13  activity            3            event      float
# 22908 2020-11-25 19:42:13  activity            4       event_type      float
#
#       value_string  value_float units
# 0              4.0          4.0  None
# 1            282.0        282.0  None
# 2           1231.0       1231.0  None
# 3          12345.0      12345.0  None
# 4      975264483.0  975264483.0  None
# ...            ...          ...   ...
# 22904          0.0          0.0  None
# 22905          1.0          1.0  None
# 22906          0.0          0.0  None
# 22907         26.0         26.0  None
# 22908          0.0          0.0  None
#
# [22909 rows x 11 columns]

# %%
for pfile in dframes.keys():
    print(pfile + ":")
    print(dframes[pfile].dtypes)
    print()
# Out:
# ../../data/parquet/Bolt_GPS.parquet:
# source_filetype              object
# source_filename              object
# manufacturer_name            object
# product_index                 int32
# timestamp            datetime64[ns]
# mesg_name                    object
# field_index                   int32
# field_name                   object
# field_type                   object
# value_string                 object
# value_float                 float64
# units                        object
# dtype: object
#
# ../../data/parquet/Who_Dares_Whoop.parquet:
# source_filetype              object
# source_filename              object
# manufacturer_name            object
# product_index                 int32
# timestamp            datetime64[ns]
# mesg_name                    object
# field_index                   int32
# field_name                   object
# field_type                   object
# value_string                 object
# value_float                 float64
# units                        object
# dtype: object
#
# ../../data/parquet/Who_Dares_Bolt.parquet:
# source_filetype              object
# source_filename              object
# manufacturer_name            object
# product_index                 int32
# timestamp            datetime64[ns]
# mesg_name                    object
# field_index                   int32
# field_name                   object
# field_type                   object
# value_string                 object
# value_float                 float64
# units                        object
# dtype: object
#
# ../../data/parquet/Who_Dares_Sufferfest.parquet:
# source_filename              object
# manufacturer_name            object
# product_index                 int32
# timestamp            datetime64[ns]
# mesg_name                    object
# field_index                   int32
# field_name                   object
# field_type                   object
# value_string                 object
# value_float                 float64
# units                        object
# dtype: object
