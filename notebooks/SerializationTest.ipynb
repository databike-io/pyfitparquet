# %%
import pyarrow
import pandas as pd
import os, re, time
from pyfitparquet import transformer

# %%
# USER: must set DATA_DIR to location of .fit/.tcx files
# Defaults PARQUET_DIR to subdirectory within DATA_DIR

DATA_DIR = '../../data'
PARQUET_DIR = DATA_DIR + '/parquet'

try: os.mkdir(PARQUET_DIR) 
except FileExistsError: pass

# %%
# Serializes all files in DATA_DIR to parquet
pyfitparq = transformer.PyFitParquet()
pyfitparq.data_to_parquet(DATA_DIR)
# Out:
# Serialized ../../data/Bolt_GPS.fit => ../../data/parquet/Bolt_GPS.parquet in 13.838 sec
# Serialized ../../data/activity_607442311.tcx => ../../data/parquet/activity_607442311.parquet in 1.206 sec
# Serialized ../../data/Who_Dares_Whoop.fit => ../../data/parquet/Who_Dares_Whoop.parquet in 0.159 sec
# Serialized ../../data/60_min_Power_Zone_Endurance_Ride_with_Christine_D_Ercole.tcx => ../../data/parquet/60_min_Power_Zone_Endurance_Ride_with_Christine_D_Ercole.parquet in 0.441 sec
# Serialized ../../data/TeamScream.tcx => ../../data/parquet/TeamScream.parquet in 0.984 sec
# Serialized ../../data/activity_4564516081.tcx => ../../data/parquet/activity_4564516081.parquet in 0.548 sec
# Serialized ../../data/dav_track_5k.tcx => ../../data/parquet/dav_track_5k.parquet in 0.050 sec
# Serialized ../../data/Who_Dares_Bolt.fit => ../../data/parquet/Who_Dares_Bolt.parquet in 1.027 sec
# Serialized ../../data/45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx => ../../data/parquet/45_min_Power_Zone_Ride_with_Matt_Wilpers.parquet in 0.269 sec
# Serialized ../../data/Who_Dares_Sufferfest.fit => ../../data/parquet/Who_Dares_Sufferfest.parquet in 0.576 sec
# Serialized ../../data/twin_cities_marathon.tcx => ../../data/parquet/twin_cities_marathon.parquet in 0.587 sec
# Serialized ../../data/new_river_50k.tcx => ../../data/parquet/new_river_50k.parquet in 0.631 sec
# Serialized ../../data/45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx => ../../data/parquet/45_min_HIIT_Hills_Ride_with_Sam_Yo.parquet in 0.332 sec

# %%
# Opens transformed parquet files into
# dataframes and display their summaries

dframes = {}
for file in os.listdir(PARQUET_DIR):
#{
    matchobj = re.match('(\w+).parquet', file)
    if matchobj:
        pfile = f'{PARQUET_DIR}/{file}'
        print(pfile + ":")
        pdframe = pd.read_parquet(pfile, engine='pyarrow')
        dframes[pfile] = pdframe
        display(pdframe)
        #display(pdframe[60:120])
        print()
#}
# Out:
# ../../data/parquet/45_min_Power_Zone_Ride_with_Matt_Wilpers.parquet:
#                                    source_filename manufacturer_name  \
# 0     45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 1     45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 2     45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 3     45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 4     45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# ...                                            ...               ...
# 5175  45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 5176  45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 5177  45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 5178  45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
# 5179  45_min_Power_Zone_Ride_with_Matt_Wilpers.tcx      Peloton Bike
#
#      product_index           timestamp   mesg_name field_index     field_name  \
# 0             None 2021-01-13 20:05:02    Activity        None          sport
# 1             None 2021-01-13 20:05:05     Creator        None           name
# 2             None 2021-01-13 20:05:05         Lap        None     total_time
# 3             None 2021-01-13 20:05:05         Lap        None       distance
# 4             None 2021-01-13 20:05:05         Lap        None  maximum_speed
# ...            ...                 ...         ...         ...            ...
# 5175          None 2021-01-13 20:50:02  Trackpoint        None       distance
# 5176          None 2021-01-13 20:50:02  Trackpoint        None     heart_rate
# 5177          None 2021-01-13 20:50:02  Trackpoint        None        cadence
# 5178          None 2021-01-13 20:50:02  Trackpoint        None          Speed
# 5179          None 2021-01-13 20:50:02  Trackpoint        None          power
#
#      field_type  value_string  value_float  units
# 0        string        Biking          NaN   None
# 1        string  Peloton Bike          NaN   None
# 2       integer          2700      2700.00      s
# 3         float      17187.75     17187.75      m
# 4         float         10.33        10.33    m/s
# ...         ...           ...          ...    ...
# 5175      float      17187.75     17187.75      m
# 5176      float         151.0       151.00    bmp
# 5177      float          91.0        91.00    rpm
# 5178      float          4.57         4.57    m/s
# 5179      float          36.0        36.00  watts
#
# [5180 rows x 11 columns]
# ../../data/parquet/Who_Dares_Whoop.parquet:
#           source_filename manufacturer_name  product_index  \
# 0     Who_Dares_Whoop.fit             WHOOP              3
# 1     Who_Dares_Whoop.fit             WHOOP              3
# 2     Who_Dares_Whoop.fit             WHOOP              3
# 3     Who_Dares_Whoop.fit             WHOOP              3
# 4     Who_Dares_Whoop.fit             WHOOP              3
# ...                   ...               ...            ...
# 5407  Who_Dares_Whoop.fit             WHOOP              3
# 5408  Who_Dares_Whoop.fit             WHOOP              3
# 5409  Who_Dares_Whoop.fit             WHOOP              3
# 5410  Who_Dares_Whoop.fit             WHOOP              3
# 5411  Who_Dares_Whoop.fit             WHOOP              3
#
#                timestamp mesg_name  field_index     field_name field_type  \
# 0                    NaT   file_id            1   manufacturer    integer
# 1                    NaT   file_id            0           type    integer
# 2                    NaT   file_id            2        product    integer
# 3                    NaT   file_id            3  serial_number    integer
# 4    2020-11-25 19:00:06   session          253      timestamp    integer
# ...                  ...       ...          ...            ...        ...
# 5407 2020-11-25 19:43:21    record            3     heart_rate    integer
# 5408 2020-11-25 19:43:22    record          253      timestamp    integer
# 5409 2020-11-25 19:43:22    record            3     heart_rate    integer
# 5410 2020-11-25 19:43:23    record          253      timestamp    integer
# 5411 2020-11-25 19:43:23    record            3     heart_rate    integer
#
#      value_string  value_float units
# 0             305        305.0  None
# 1               4          4.0  None
# 2               3          3.0  None
# 3           12345      12345.0  None
# 4       975265206  975265206.0     s
# ...           ...          ...   ...
# 5407          135        135.0   bpm
# 5408    975267802  975267802.0     s
# 5409          133        133.0   bpm
# 5410    975267803  975267803.0     s
# 5411          133        133.0   bpm
#
# [5412 rows x 11 columns]
# ../../data/parquet/activity_607442311.parquet:
#               source_filename      manufacturer_name product_index  \
# 0      activity_607442311.tcx  Garmin Forerunner 620          1623
# 1      activity_607442311.tcx  Garmin Forerunner 620          1623
# 2      activity_607442311.tcx  Garmin Forerunner 620          1623
# 3      activity_607442311.tcx  Garmin Forerunner 620          1623
# 4      activity_607442311.tcx  Garmin Forerunner 620          1623
# ...                       ...                    ...           ...
# 11501  activity_607442311.tcx  Garmin Forerunner 620          1623
# 11502  activity_607442311.tcx  Garmin Forerunner 620          1623
# 11503  activity_607442311.tcx  Garmin Forerunner 620          1623
# 11504  activity_607442311.tcx  Garmin Forerunner 620          1623
# 11505  activity_607442311.tcx  Garmin Forerunner 620          1623
#
#                 timestamp mesg_name field_index     field_name field_type  \
# 0     2014-10-05 13:07:53  Activity        None          sport     string
# 1     2014-10-05 13:07:53       Lap        None     total_time      float
# 2     2014-10-05 13:07:53       Lap        None       distance      float
# 3     2014-10-05 13:07:53       Lap        None  maximum_speed      float
# 4     2014-10-05 13:07:53       Lap        None       calories    integer
# ...                   ...       ...         ...            ...        ...
# 11501 2014-10-05 17:22:17   Creator        None  version_major    integer
# 11502 2014-10-05 17:22:17   Creator        None  version_minor    integer
# 11503 2014-10-05 17:22:17   Creator        None    build_major    integer
# 11504 2014-10-05 17:22:17   Creator        None    build_minor    integer
# 11505 2014-10-05 17:22:17    Author        None           type     string
#
#             value_string  value_float units
# 0                Running          NaN  None
# 1                  535.0      535.000     s
# 2                1609.35     1609.350     m
# 3      6.401000022888184        6.401   m/s
# 4                    108      108.000  kcal
# ...                  ...          ...   ...
# 11501                  3        3.000  None
# 11502                  0        0.000  None
# 11503                  0        0.000  None
# 11504                  0        0.000  None
# 11505      Application_t          NaN  None
#
# [11506 rows x 11 columns]
# ../../data/parquet/activity_4564516081.parquet:
#                source_filename manufacturer_name product_index  \
# 0      activity_4564516081.tcx    Forerunner 235          2431
# 1      activity_4564516081.tcx    Forerunner 235          2431
# 2      activity_4564516081.tcx    Forerunner 235          2431
# 3      activity_4564516081.tcx    Forerunner 235          2431
# 4      activity_4564516081.tcx    Forerunner 235          2431
# ...                        ...               ...           ...
# 11106  activity_4564516081.tcx    Forerunner 235          2431
# 11107  activity_4564516081.tcx    Forerunner 235          2431
# 11108  activity_4564516081.tcx    Forerunner 235          2431
# 11109  activity_4564516081.tcx    Forerunner 235          2431
# 11110  activity_4564516081.tcx    Forerunner 235          2431
#
#                 timestamp mesg_name field_index     field_name field_type  \
# 0     2020-02-17 17:15:02  Activity        None          sport     string
# 1     2020-02-17 17:15:02       Lap        None     total_time      float
# 2     2020-02-17 17:15:02       Lap        None       distance      float
# 3     2020-02-17 17:15:02       Lap        None  maximum_speed      float
# 4     2020-02-17 17:15:02       Lap        None       calories    integer
# ...                   ...       ...         ...            ...        ...
# 11106 2020-02-17 20:06:28   Creator        None  version_major    integer
# 11107 2020-02-17 20:06:28   Creator        None  version_minor    integer
# 11108 2020-02-17 20:06:28   Creator        None    build_major    integer
# 11109 2020-02-17 20:06:28   Creator        None    build_minor    integer
# 11110 2020-02-17 20:06:28    Author        None           type     string
#
#             value_string  value_float units
# 0                Running          NaN  None
# 1                  663.0      663.000     s
# 2                1609.34     1609.340     m
# 3      3.003999948501587        3.004   m/s
# 4                    133      133.000  kcal
# ...                  ...          ...   ...
# 11106                  7        7.000  None
# 11107                 90       90.000  None
# 11108                  0        0.000  None
# 11109                  0        0.000  None
# 11110      Application_t          NaN  None
#
# [11111 rows x 11 columns]
# ../../data/parquet/Who_Dares_Sufferfest.parquet:
#                 source_filename manufacturer_name  product_index  \
# 0      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 1      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 2      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 3      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 4      Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# ...                         ...               ...            ...
# 22904  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22905  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22906  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22907  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
# 22908  Who_Dares_Sufferfest.fit    THE_SUFFERFEST           1231
#
#                 timestamp mesg_name  field_index       field_name field_type  \
# 0     2020-11-25 18:48:03   file_id            0             type    integer
# 1     2020-11-25 18:48:03   file_id            1     manufacturer    integer
# 2     2020-11-25 18:48:03   file_id            2          product    integer
# 3     2020-11-25 18:48:03   file_id            3    serial_number    integer
# 4     2020-11-25 18:48:03   file_id            4     time_created    integer
# ...                   ...       ...          ...              ...        ...
# 22904 2020-11-25 19:42:13  activity            5  local_timestamp    integer
# 22905 2020-11-25 19:42:13  activity            1     num_sessions    integer
# 22906 2020-11-25 19:42:13  activity            2             type    integer
# 22907 2020-11-25 19:42:13  activity            3            event    integer
# 22908 2020-11-25 19:42:13  activity            4       event_type    integer
#
#       value_string  value_float units
# 0                4          4.0  None
# 1              282        282.0  None
# 2             1231       1231.0  None
# 3            12345      12345.0  None
# 4        975264483  975264483.0  None
# ...            ...          ...   ...
# 22904            0          0.0  None
# 22905            1          1.0  None
# 22906            0          0.0  None
# 22907           26         26.0  None
# 22908            0          0.0  None
#
# [22909 rows x 11 columns]
# ../../data/parquet/Bolt_GPS.parquet:
#        source_filename manufacturer_name  product_index           timestamp  \
# 0         Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 16:48:11
# 1         Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 16:48:11
# 2         Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 16:48:11
# 3         Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 16:48:11
# 4         Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 16:48:11
# ...                ...               ...            ...                 ...
# 360351    Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 22:49:26
# 360352    Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 22:49:26
# 360353    Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 22:49:26
# 360354    Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 22:49:26
# 360355    Bolt_GPS.fit     WAHOO_FITNESS             31 2020-08-30 22:49:26
#
#        mesg_name  field_index        field_name field_type value_string  \
# 0        file_id            4      time_created    integer    967740491
# 1        file_id            0              type    integer            4
# 2        file_id            1      manufacturer    integer           32
# 3        file_id            2           product    integer           31
# 4        file_id            3     serial_number    integer   3338297344
# ...          ...          ...               ...        ...          ...
# 360351  activity            1      num_sessions    integer            1
# 360352  activity            2              type    integer            0
# 360353  activity            3             event    integer           26
# 360354  activity            4        event_type    integer            1
# 360355  activity            0  total_timer_time      float        21676
#
#          value_float units
# 0       9.677405e+08  None
# 1       4.000000e+00  None
# 2       3.200000e+01  None
# 3       3.100000e+01  None
# 4       3.338297e+09  None
# ...              ...   ...
# 360351  1.000000e+00  None
# 360352  0.000000e+00  None
# 360353  2.600000e+01  None
# 360354  1.000000e+00  None
# 360355  2.167600e+04     s
#
# [360356 rows x 11 columns]
# ../../data/parquet/TeamScream.parquet:
#       source_filename               manufacturer_name product_index  \
# 0      TeamScream.tcx  The Sufferfest Training System             1
# 1      TeamScream.tcx  The Sufferfest Training System             1
# 2      TeamScream.tcx  The Sufferfest Training System             1
# 3      TeamScream.tcx  The Sufferfest Training System             1
# 4      TeamScream.tcx  The Sufferfest Training System             1
# ...               ...                             ...           ...
# 20761  TeamScream.tcx  The Sufferfest Training System             1
# 20762  TeamScream.tcx  The Sufferfest Training System             1
# 20763  TeamScream.tcx  The Sufferfest Training System             1
# 20764  TeamScream.tcx  The Sufferfest Training System             1
# 20765  TeamScream.tcx  The Sufferfest Training System             1
#
#                 timestamp mesg_name field_index          field_name  \
# 0     2021-01-09 16:40:10  Activity        None               sport
# 1     2021-01-09 16:40:10       Lap        None  average_heart_rate
# 2     2021-01-09 16:40:10       Lap        None            calories
# 3     2021-01-09 16:40:11       Lap        None            distance
# 4     2021-01-09 16:40:11       Lap        None           intensity
# ...                   ...       ...         ...                 ...
# 20761 2021-01-09 17:49:39   Creator        None             unit_id
# 20762 2021-01-09 17:49:39   Creator        None         build_major
# 20763 2021-01-09 17:49:39   Creator        None         build_minor
# 20764 2021-01-09 17:49:39   Creator        None       version_major
# 20765 2021-01-09 17:49:39   Creator        None       version_minor
#
#       field_type value_string  value_float units
# 0         string       Biking          NaN  None
# 1        integer          178       178.00   bpm
# 2        integer          913       913.00  kcal
# 3          float     38175.74     38175.74     m
# 4         string       Active          NaN  None
# ...          ...          ...          ...   ...
# 20761    integer            1         1.00  None
# 20762    integer            0         0.00  None
# 20763    integer            0         0.00  None
# 20764    integer            1         1.00  None
# 20765    integer            0         0.00  None
#
# [20766 rows x 11 columns]
# ../../data/parquet/new_river_50k.parquet:
#         source_filename      manufacturer_name product_index  \
# 0     new_river_50k.tcx  Garmin Forerunner 620          1623
# 1     new_river_50k.tcx  Garmin Forerunner 620          1623
# 2     new_river_50k.tcx  Garmin Forerunner 620          1623
# 3     new_river_50k.tcx  Garmin Forerunner 620          1623
# 4     new_river_50k.tcx  Garmin Forerunner 620          1623
# ...                 ...                    ...           ...
# 8109  new_river_50k.tcx  Garmin Forerunner 620          1623
# 8110  new_river_50k.tcx  Garmin Forerunner 620          1623
# 8111  new_river_50k.tcx  Garmin Forerunner 620          1623
# 8112  new_river_50k.tcx  Garmin Forerunner 620          1623
# 8113  new_river_50k.tcx  Garmin Forerunner 620          1623
#
#                timestamp mesg_name field_index     field_name field_type  \
# 0    2015-10-17 12:00:12  Activity        None          sport     string
# 1    2015-10-17 12:00:12       Lap        None     total_time      float
# 2    2015-10-17 12:00:12       Lap        None       distance      float
# 3    2015-10-17 12:00:22       Lap        None  maximum_speed      float
# 4    2015-10-17 12:00:22       Lap        None       calories    integer
# ...                  ...       ...         ...            ...        ...
# 8109 2015-10-17 17:42:30   Creator        None  version_major    integer
# 8110 2015-10-17 17:42:30   Creator        None  version_minor    integer
# 8111 2015-10-17 17:42:30   Creator        None    build_major    integer
# 8112 2015-10-17 17:42:30   Creator        None    build_minor    integer
# 8113 2015-10-17 17:42:30    Author        None           type     string
#
#             value_string  value_float units
# 0                Running          NaN  None
# 1                622.551      622.551     s
# 2                1609.35     1609.350     m
# 3     2.8459999561309814        2.846   m/s
# 4                    120      120.000  kcal
# ...                  ...          ...   ...
# 8109                   3        3.000  None
# 8110                  30       30.000  None
# 8111                   0        0.000  None
# 8112                   0        0.000  None
# 8113       Application_t          NaN  None
#
# [8114 rows x 11 columns]
# ../../data/parquet/60_min_Power_Zone_Endurance_Ride_with_Christine_D_Ercole.parquet:
#                                         source_filename manufacturer_name  \
# 0     60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 1     60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 2     60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 3     60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 4     60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# ...                                                 ...               ...
# 8565  60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 8566  60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 8567  60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 8568  60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
# 8569  60_min_Power_Zone_Endurance_Ride_with_Christin...      Peloton Bike
#
#      product_index           timestamp   mesg_name field_index     field_name  \
# 0             None 2021-01-12 21:00:37    Activity        None          sport
# 1             None 2021-01-12 21:00:39     Creator        None           name
# 2             None 2021-01-12 21:00:39         Lap        None     total_time
# 3             None 2021-01-12 21:00:39         Lap        None       distance
# 4             None 2021-01-12 21:00:39         Lap        None  maximum_speed
# ...            ...                 ...         ...         ...            ...
# 8565          None 2021-01-12 22:00:36  Trackpoint        None       distance
# 8566          None 2021-01-12 22:00:36  Trackpoint        None     heart_rate
# 8567          None 2021-01-12 22:00:36  Trackpoint        None        cadence
# 8568          None 2021-01-12 22:00:36  Trackpoint        None          Speed
# 8569          None 2021-01-12 22:00:36  Trackpoint        None          power
#
#      field_type  value_string  value_float  units
# 0        string        Biking          NaN   None
# 1        string  Peloton Bike          NaN   None
# 2       integer          3600      3600.00      s
# 3         float      27535.81     27535.81      m
# 4         float          9.27         9.27    m/s
# ...         ...           ...          ...    ...
# 8565      float      27535.81     27535.81      m
# 8566      float         125.0       125.00    bmp
# 8567      float          96.0        96.00    rpm
# 8568      float          5.24         5.24    m/s
# 8569      float          47.7        47.70  watts
#
# [8570 rows x 11 columns]
# ../../data/parquet/twin_cities_marathon.parquet:
#                 source_filename      manufacturer_name product_index  \
# 0      twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 1      twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 2      twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 3      twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 4      twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# ...                         ...                    ...           ...
# 11501  twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 11502  twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 11503  twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 11504  twin_cities_marathon.tcx  Garmin Forerunner 620          1623
# 11505  twin_cities_marathon.tcx  Garmin Forerunner 620          1623
#
#                 timestamp mesg_name field_index     field_name field_type  \
# 0     2014-10-05 13:07:53  Activity        None          sport     string
# 1     2014-10-05 13:07:53       Lap        None     total_time      float
# 2     2014-10-05 13:07:53       Lap        None       distance      float
# 3     2014-10-05 13:07:53       Lap        None  maximum_speed      float
# 4     2014-10-05 13:07:53       Lap        None       calories    integer
# ...                   ...       ...         ...            ...        ...
# 11501 2014-10-05 17:22:17   Creator        None  version_major    integer
# 11502 2014-10-05 17:22:17   Creator        None  version_minor    integer
# 11503 2014-10-05 17:22:17   Creator        None    build_major    integer
# 11504 2014-10-05 17:22:17   Creator        None    build_minor    integer
# 11505 2014-10-05 17:22:17    Author        None           type     string
#
#             value_string  value_float units
# 0                Running          NaN  None
# 1                534.797      534.797     s
# 2                1609.35     1609.350     m
# 3      6.401000022888184        6.401   m/s
# 4                    108      108.000  kcal
# ...                  ...          ...   ...
# 11501                  3        3.000  None
# 11502                  0        0.000  None
# 11503                  0        0.000  None
# 11504                  0        0.000  None
# 11505      Application_t          NaN  None
#
# [11506 rows x 11 columns]
# ../../data/parquet/45_min_HIIT_Hills_Ride_with_Sam_Yo.parquet:
#                              source_filename manufacturer_name product_index  \
# 0     45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 1     45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 2     45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 3     45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 4     45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# ...                                      ...               ...           ...
# 6605  45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 6606  45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 6607  45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 6608  45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
# 6609  45_min_HIIT_Hills_Ride_with_Sam_Yo.tcx      Peloton Bike          None
#
#                timestamp   mesg_name field_index     field_name field_type  \
# 0    2020-10-28 16:31:36    Activity        None          sport     string
# 1    2020-10-28 16:31:37     Creator        None           name     string
# 2    2020-10-28 16:31:37         Lap        None     total_time    integer
# 3    2020-10-28 16:31:37         Lap        None       distance      float
# 4    2020-10-28 16:31:37         Lap        None  maximum_speed      float
# ...                  ...         ...         ...            ...        ...
# 6605 2020-10-28 17:16:36  Trackpoint        None       distance      float
# 6606 2020-10-28 17:16:36  Trackpoint        None     heart_rate      float
# 6607 2020-10-28 17:16:36  Trackpoint        None        cadence      float
# 6608 2020-10-28 17:16:36  Trackpoint        None          Speed      float
# 6609 2020-10-28 17:16:36  Trackpoint        None          power      float
#
#       value_string  value_float  units
# 0           Biking          NaN   None
# 1     Peloton Bike          NaN   None
# 2             2700      2700.00      s
# 3         21227.19     21227.19      m
# 4             11.4        11.40    m/s
# ...            ...          ...    ...
# 6605      21227.19     21227.19      m
# 6606         143.0       143.00    bmp
# 6607          81.0        81.00    rpm
# 6608          5.41         5.41    m/s
# 6609          50.9        50.90  watts
#
# [6610 rows x 11 columns]
# ../../data/parquet/dav_track_5k.parquet:
#       source_filename      manufacturer_name product_index  \
# 0    dav_track_5k.tcx  Garmin Forerunner 620          1623
# 1    dav_track_5k.tcx  Garmin Forerunner 620          1623
# 2    dav_track_5k.tcx  Garmin Forerunner 620          1623
# 3    dav_track_5k.tcx  Garmin Forerunner 620          1623
# 4    dav_track_5k.tcx  Garmin Forerunner 620          1623
# ..                ...                    ...           ...
# 764  dav_track_5k.tcx  Garmin Forerunner 620          1623
# 765  dav_track_5k.tcx  Garmin Forerunner 620          1623
# 766  dav_track_5k.tcx  Garmin Forerunner 620          1623
# 767  dav_track_5k.tcx  Garmin Forerunner 620          1623
# 768  dav_track_5k.tcx  Garmin Forerunner 620          1623
#
#               timestamp mesg_name field_index     field_name field_type  \
# 0   2015-10-01 11:31:59  Activity        None          sport     string
# 1   2015-10-01 11:31:59       Lap        None     total_time      float
# 2   2015-10-01 11:31:59       Lap        None       distance      float
# 3   2015-10-01 11:32:06       Lap        None  maximum_speed      float
# 4   2015-10-01 11:32:06       Lap        None       calories    integer
# ..                  ...       ...         ...            ...        ...
# 764 2015-10-01 11:58:55   Creator        None  version_major    integer
# 765 2015-10-01 11:58:55   Creator        None  version_minor    integer
# 766 2015-10-01 11:58:55   Creator        None    build_major    integer
# 767 2015-10-01 11:58:55   Creator        None    build_minor    integer
# 768 2015-10-01 11:58:55    Author        None           type     string
#
#            value_string  value_float units
# 0               Running          NaN  None
# 1               506.486      506.486     s
# 2               1609.35     1609.350     m
# 3    3.7699999809265137        3.770   m/s
# 4                   121      121.000  kcal
# ..                  ...          ...   ...
# 764                   3        3.000  None
# 765                  30       30.000  None
# 766                   0        0.000  None
# 767                   0        0.000  None
# 768       Application_t          NaN  None
#
# [769 rows x 11 columns]
# ../../data/parquet/Who_Dares_Bolt.parquet:
#           source_filename manufacturer_name  product_index  \
# 0      Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 1      Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 2      Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 3      Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 4      Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# ...                   ...               ...            ...
# 36394  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36395  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36396  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36397  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
# 36398  Who_Dares_Bolt.fit     WAHOO_FITNESS             31
#
#                 timestamp mesg_name  field_index        field_name field_type  \
# 0     2020-11-25 18:48:44   file_id            4      time_created    integer
# 1     2020-11-25 18:48:44   file_id            0              type    integer
# 2     2020-11-25 18:48:44   file_id            1      manufacturer    integer
# 3     2020-11-25 18:48:44   file_id            2           product    integer
# 4     2020-11-25 18:48:44   file_id            3     serial_number    integer
# ...                   ...       ...          ...               ...        ...
# 36394 2020-11-25 19:43:38  activity            1      num_sessions    integer
# 36395 2020-11-25 19:43:38  activity            2              type    integer
# 36396 2020-11-25 19:43:38  activity            3             event    integer
# 36397 2020-11-25 19:43:38  activity            4        event_type    integer
# 36398 2020-11-25 19:43:38  activity            0  total_timer_time      float
#
#       value_string   value_float units
# 0        975264524  9.752645e+08  None
# 1                4  4.000000e+00  None
# 2               32  3.200000e+01  None
# 3               31  3.100000e+01  None
# 4       3338297344  3.338297e+09  None
# ...            ...           ...   ...
# 36394            1  1.000000e+00  None
# 36395            0  0.000000e+00  None
# 36396           26  2.600000e+01  None
# 36397            1  1.000000e+00  None
# 36398         3294  3.294000e+03     s
#
# [36399 rows x 11 columns]

# %%
# Test re-initialization from configuation file
# USER: make some change to parquet_config.yml

pyfitparq.reset_from_config()
pyfitparq.data_to_parquet(DATA_DIR)

# %%
# Opens transformed parquet files into
# dataframes and display their summaries

dframes = {}
for file in os.listdir(PARQUET_DIR):
#{
    matchobj = re.match('(\w+).parquet', file)
    if matchobj:
        pfile = f'{PARQUET_DIR}/{file}'
        print(pfile + ":")
        pdframe = pd.read_parquet(pfile, engine='pyarrow')
        dframes[pfile] = pdframe
        display(pdframe)
        #display(pdframe[60:120])
        print()
#}

# %%
for pfile in dframes.keys():
    print(pfile + ":")
    print(dframes[pfile].dtypes)
    print()
